# %% [markdown]
# ## Import Dependencies

# %%
from pathlib import Path
from PIL import Image
from torch.utils.data import Dataset
from numpy import random
import torchvision
import torch
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np
from IPython.display import display, clear_output
import os
os.environ["KMP_DUPLICATE_LIB_OK"]="TRUE"

# %% [markdown]
# ## Import Models

# %%
from models import Generator, Discriminator, Facades

# %% [markdown]
# ## Import Trained Parameters

# %%
inference = torch.load("Pix2Pix.pth")

# %% [markdown]
# ## Put Parameters into Models

# %%
gen_i = Generator().cuda()
disc_i = Discriminator().cuda()

# %%
gen_i.load_state_dict(inference['gen_state_dict'])
disc_i.load_state_dict(inference['disc_state_dict'])

# %% [markdown]
# ## Load Some Images to See How the Model Did

# %%
facades = Facades(targ_dir="../data/facades", train=False)

# %%
def slideshow_facades() -> None:
    _, axarr = plt.subplots(1 ,2, figsize=(12, 6))
    
    r_num = np.random.randint(0, len(facades))
    real, input = facades[r_num]
    real = real.numpy()
    input = input.numpy()

    axarr[0].imshow(np.transpose(real,  (1, 2, 0)))
    axarr[1].imshow(np.transpose(input, (1, 2, 0)))

    axarr[0].title.set_text(f"Real: {real.shape}")
    axarr[1].title.set_text(f"Input: {input.shape}")
    
    axarr[0].axis('off')
    axarr[1].axis('off')

# %%
for _ in range(5):
    slideshow_facades()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
